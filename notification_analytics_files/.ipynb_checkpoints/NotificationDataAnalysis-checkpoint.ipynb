# %%
# Import Necessary Libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Dataset Information
#
# The Notification Log data used for this analysis was collected from my personal phone over a period of over 30 hours with the help of a free android app- __Notification Log__. A vast range of notification information was collected and analysed below.

# %%
# Load the Notifications Dataset
notifications_df = pd.read_csv("notification_data.csv")

# %% [markdown]
# ### Data Exploration
#
# Understanding the basic nature of the notification dataset

# %%
notifications_df.sample(10)
# Out:
#                         packageName       postTime     systemTime   offset  \
# 386                    com.whatsapp  1659658966806  1659658967095  7200000
# 2043            com.android.vending  1659709718559  1659709718786  7200000
# 1047                   com.whatsapp  1659695741966  1659695742237  7200000
# 1381    com.sec.android.app.shealth  1659699626659  1659699857465  7200000
# 369            com.android.systemui  1659658722485  1659658722744  7200000
# 2295           com.android.systemui  1659713332509  1659713332765  7200000
# 4324  com.a0soft.gphone.uninstaller  1659739347575  1659739348245  7200000
# 3231                        android  1659719959253  1659719961024  7200000
# 620          com.google.android.gms  1659681128529  1659681129815  7200000
# 3571    com.sec.android.app.shealth  1659725792456  1659725792687  7200000
#
#       version  sdk  isOngoing  isClearable           when  number  ...  \
# 386        16   30       True        False  1659658966781      -1  ...
# 2043       16   30       True        False  1659709718551      -1  ...
# 1047       16   30      False         True  1659695741160      -1  ...
# 1381       16   30       True        False  1659699626651      -1  ...
# 369        16   30       True        False              0      -1  ...
# 2295       16   30       True        False              0      -1  ...
# 4324       16   30       True        False              0      -1  ...
# 3231       16   30       True        False  1659719959140      -1  ...
# 620        16   30       True        False  1659681128383      -1  ...
# 3571       16   30       True        False  1659725792442      -1  ...
#
#                                                     key  visibility     color  \
# 386                        0|com.whatsapp|11|null|10001           0 -16744343
# 2043         0|com.android.vending|-56862258|null|10057          -1 -16677025
# 1047                        0|com.whatsapp|1|null|10001           0 -16744343
# 1381       0|com.sec.android.app.shealth|105|null|10184           0         0
# 369   -1|com.android.systemui|2131362956|charging_st...           1  -7827550
# 2295  -1|com.android.systemui|2131362956|charging_st...           1  -7827550
# 4324     0|com.a0soft.gphone.uninstaller|103|null|10439           0  -1684967
# 3231  0|android|0|com.android.server.wm.AlertWindowN...           0  -7827550
# 620      0|com.google.android.gms|2131362207|null|10035           0 -16423862
# 3571       0|com.sec.android.app.shealth|105|null|10184           0         0
#
#       interruptionFilter  listenerHints  matchesInterruptionFilter  \
# 386                    1              0                       True
# 2043                   1              0                       True
# 1047                   1              0                       True
# 1381                   1              0                       True
# 369                    1              0                       True
# 2295                   1              0                       True
# 4324                   1              0                       True
# 3231                   1              0                       True
# 620                    1              0                       True
# 3571                   1              0                       True
#
#                                                   style  category  \
# 386                                                 NaN       NaN
# 2043                                                NaN       NaN
# 1047                android.app.Notification$InboxStyle       msg
# 1381              android.app.Notification$BigTextStyle       NaN
# 369               android.app.Notification$BigTextStyle       sys
# 2295              android.app.Notification$BigTextStyle       sys
# 4324  android.app.Notification$DecoratedCustomViewStyle       NaN
# 3231              android.app.Notification$BigTextStyle       NaN
# 620                                                 NaN   service
# 3571              android.app.Notification$BigTextStyle       NaN
#
#                                               textLines  sortKey
# 386                                                 NaN      NaN
# 2043                                                NaN      NaN
# 1047  +250 789 652 451 @ ALUmni CLASS OF 2022: Yea I...      NaN
# 1381                                                NaN      NaN
# 369                                                 NaN      NaN
# 2295                                                NaN      NaN
# 4324                                                NaN      NaN
# 3231                                                NaN      NaN
# 620                                                 NaN      NaN
# 3571                                                NaN      NaN
#
# [10 rows x 49 columns]

# %%
# Check Shape of Dataset
notifications_df.shape
# Out:
# (4544, 49)

# %%
# Check Available Columns
notifications_df.columns
# Out:
# Index(['packageName', 'postTime', 'systemTime', 'offset', 'version', 'sdk',
#        'isOngoing', 'isClearable', 'when', 'number', 'flags', 'defaults',
#        'ledARGB', 'ledOn', 'ledOff', 'ringerMode', 'isScreenOn',
#        'batteryLevel', 'batteryStatus', 'isConnected', 'connectionType',
#        'hasAppointment', 'group', 'isGroupSummary', 'actionCount',
#        'isLocalOnly', 'people', 'tickerText', 'title', 'titleBig', 'text',
#        'textBig', 'textInfo', 'textSub', 'textSummary', 'appName', 'priority',
#        'nid', 'tag', 'key', 'visibility', 'color', 'interruptionFilter',
#        'listenerHints', 'matchesInterruptionFilter', 'style', 'category',
#        'textLines', 'sortKey'],
#       dtype='object')

# %%
# Check Basic Notification Dataset Information
notifications_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4544 entries, 0 to 4543
# Data columns (total 49 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   packageName                4544 non-null   object
#  1   postTime                   4544 non-null   int64
#  2   systemTime                 4544 non-null   int64
#  3   offset                     4544 non-null   int64
#  4   version                    4544 non-null   int64
#  5   sdk                        4544 non-null   int64
#  6   isOngoing                  4544 non-null   bool
#  7   isClearable                4544 non-null   bool
#  8   when                       4544 non-null   int64
#  9   number                     4544 non-null   int64
#  10  flags                      4544 non-null   int64
#  11  defaults                   4544 non-null   int64
#  12  ledARGB                    4544 non-null   int64
#  13  ledOn                      4544 non-null   int64
#  14  ledOff                     4544 non-null   int64
#  15  ringerMode                 4544 non-null   int64
#  16  isScreenOn                 4544 non-null   bool
#  17  batteryLevel               4544 non-null   int64
#  18  batteryStatus              4544 non-null   object
#  19  isConnected                4544 non-null   bool
#  20  connectionType             4544 non-null   object
#  21  hasAppointment             4544 non-null   bool
#  22  group                      2588 non-null   object
#  23  isGroupSummary             4544 non-null   bool
#  24  actionCount                4544 non-null   int64
#  25  isLocalOnly                4544 non-null   bool
#  26  people                     4544 non-null   int64
#  27  tickerText                 767 non-null    object
#  28  title                      4415 non-null   object
#  29  titleBig                   914 non-null    object
#  30  text                       4131 non-null   object
#  31  textBig                    2094 non-null   object
#  32  textInfo                   21 non-null     object
#  33  textSub                    424 non-null    object
#  34  textSummary                139 non-null    object
#  35  appName                    4544 non-null   object
#  36  priority                   4544 non-null   int64
#  37  nid                        4544 non-null   int64
#  38  tag                        1579 non-null   object
#  39  key                        4544 non-null   object
#  40  visibility                 4544 non-null   int64
#  41  color                      4544 non-null   int64
#  42  interruptionFilter         4544 non-null   int64
#  43  listenerHints              4544 non-null   int64
#  44  matchesInterruptionFilter  4544 non-null   bool
#  45  style                      3639 non-null   object
#  46  category                   1282 non-null   object
#  47  textLines                  134 non-null    object
#  48  sortKey                    371 non-null    object
# dtypes: bool(8), int64(22), object(19)
# memory usage: 1.5+ MB

# %%
notifications_df.describe()
# Out:
#            postTime    systemTime     offset  version     sdk          when  \
# count  4.544000e+03  4.544000e+03     4544.0   4544.0  4544.0  4.544000e+03
# mean   1.659706e+12  1.659707e+12  7200000.0     16.0    30.0  1.013938e+12
# std    2.422396e+07  2.337514e+07        0.0      0.0     0.0  8.092645e+11
# min    1.659593e+12  1.659650e+12  7200000.0     16.0    30.0  0.000000e+00
# 25%    1.659696e+12  1.659696e+12  7200000.0     16.0    30.0  0.000000e+00
# 50%    1.659713e+12  1.659713e+12  7200000.0     16.0    30.0  1.659689e+12
# 75%    1.659721e+12  1.659721e+12  7200000.0     16.0    30.0  1.659715e+12
# max    1.659743e+12  1.659743e+12  7200000.0     16.0    30.0  1.659743e+12
#
#        number        flags  defaults  ledARGB  ...  ringerMode  batteryLevel  \
# count  4544.0  4544.000000    4544.0   4544.0  ...      4544.0   4544.000000
# mean     -1.0   105.622359       0.0      0.0  ...         1.0     39.175176
# std       0.0   142.757796       0.0      0.0  ...         0.0     16.410354
# min      -1.0     0.000000       0.0      0.0  ...         1.0      0.000000
# 25%      -1.0    10.000000       0.0      0.0  ...         1.0     27.000000
# 50%      -1.0   106.000000       0.0      0.0  ...         1.0     45.000000
# 75%      -1.0   106.000000       0.0      0.0  ...         1.0     54.000000
# max      -1.0  1794.000000       0.0      0.0  ...         1.0     56.000000
#
#        actionCount  people     priority           nid   visibility  \
# count  4544.000000  4544.0  4544.000000  4.544000e+03  4544.000000
# mean      0.427817     0.0    -0.424076  4.349260e+08     0.139085
# std       0.906397     0.0     1.571385  9.011886e+08     0.526661
# min       0.000000     0.0    -2.000000 -2.147484e+09    -1.000000
# 25%       0.000000     0.0    -2.000000  1.000000e+00     0.000000
# 50%       0.000000     0.0    -1.000000  1.030000e+02     0.000000
# 75%       0.000000     0.0     1.000000  1.050000e+02     0.000000
# max       4.000000     0.0     2.000000  2.147484e+09     1.000000
#
#               color  interruptionFilter  listenerHints
# count  4.544000e+03              4544.0         4544.0
# mean  -6.678447e+06                 1.0            0.0
# std    6.697834e+06                 0.0            0.0
# min   -1.674760e+07                 1.0            0.0
# 25%   -1.506582e+07                 1.0            0.0
# 50%   -1.684967e+06                 1.0            0.0
# 75%    0.000000e+00                 1.0            0.0
# max    0.000000e+00                 1.0            0.0
#
# [8 rows x 22 columns]

# %% [markdown]
# ### Data Cleaning & Feature Engineering
#
# In this section, I investigated the dataset's features to get a deeper understanding of the essential metrics that could be analysed for helpful insight.
#
# Data Cleaning Practices used include:
#
#            1. Removing unnecessary features/columns
#            2. Checking for & Handling Null Values.
#            3. Checking for Duplicated Notification Logs
#            4. Converting columns to their approriate data types

# %%
# drop irrelevant columns from the 2018 dataset
drop_list = ['offset', 'version', 'sdk', 'sortKey', 'textLines', 'category', 'style', 'key', 'textSummary', 'textSub', 'textInfo', 'textBig', 'titleBig', 'tickerText',
            'ringerMode', 'packageName', 'defaults', 'flags', 'listenerHints', 'color', 'visibility',
            'people', 'number', 'nid', 'matchesInterruptionFilter', 'hasAppointment', 'ledARGB', 'ledOn', 'ledOff',
            'isClearable', 'tag', 'interruptionFilter', 'group', 'isGroupSummary']

notifications_df.drop(drop_list, axis=1, inplace=True)

# confirm changes
notifications_df.head(10)
# Out:
#         postTime     systemTime  isOngoing           when  isScreenOn  \
# 0  1659624332902  1659649734578      False  1659624332807        True
# 1  1659647949583  1659649734636      False  1659647966000        True
# 2  1659647949572  1659649734675      False  1659647949548        True
# 3  1659621628790  1659649734724      False  1659621628531        True
# 4  1659592821702  1659649734752      False  1659550058000        True
# 5  1659636441864  1659649734791      False  1659636458000        True
# 6  1659647111864  1659649734808      False  1658819996375        True
# 7  1659647111848  1659649734832      False  1659647111817        True
# 8  1659636154356  1659649734855      False  1659636154235        True
# 9  1659647804894  1659649734909      False  1659647804860        True
#
#    batteryLevel batteryStatus  isConnected connectionType  actionCount  \
# 0             9   discharging         True           wifi            0
# 1             9   discharging         True           wifi            0
# 2             9   discharging         True           wifi            0
# 3             9   discharging         True           wifi            0
# 4             9   discharging         True           wifi            0
# 5             9   discharging         True           wifi            0
# 6             9   discharging         True           wifi            0
# 7             9   discharging         True           wifi            0
# 8             9   discharging         True           wifi            3
# 9             9   discharging         True           wifi            0
#
#    isLocalOnly                                              title  \
# 0        False  TERMS OF USE | Tinder | Match. Chat. Meet. Mod...
# 1        False                   Tomorrow in Kigali: Mostly sunny
# 2        False                                                NaN
# 3         True                            An account was deleted.
# 4        False                                       Chelsea News
# 5        False                                       Chelsea News
# 6        False  <master-komezart> ARTWORK DATABASE 2: 2022_Tic...
# 7        False                                                NaN
# 8        False                                   Screenshot saved
# 9        False                          Your data isn’t backed up
#
#                                                 text               appName  \
# 0                              Page is ready to view                Chrome
# 1                      26° / 16° · See full forecast                Google
# 2                                                NaN                Google
# 3         Delete apps unassociated with any account.     Google Play Store
# 4  Man City made late move to keep new Chelsea pl...                Google
# 5  Chelsea handed first big injury boost of new s...                Google
# 6  ⁨Yvan King Mukunzi⁩ resolved a comment Done: “...                 Drive
# 7                                                NaN                 Drive
# 8                    Tap here to open it in Gallery.       Samsung capture
# 9                           Add a backup account now  Google Play services
#
#    priority
# 0        -1
# 1        -1
# 2        -1
# 3        -1
# 4        -1
# 5        -1
# 6         0
# 7         0
# 8         0
# 9         1

# %%
notifications_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4544 entries, 0 to 4543
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   postTime        4544 non-null   int64
#  1   systemTime      4544 non-null   int64
#  2   isOngoing       4544 non-null   bool
#  3   when            4544 non-null   int64
#  4   isScreenOn      4544 non-null   bool
#  5   batteryLevel    4544 non-null   int64
#  6   batteryStatus   4544 non-null   object
#  7   isConnected     4544 non-null   bool
#  8   connectionType  4544 non-null   object
#  9   actionCount     4544 non-null   int64
#  10  isLocalOnly     4544 non-null   bool
#  11  title           4415 non-null   object
#  12  text            4131 non-null   object
#  13  appName         4544 non-null   object
#  14  priority        4544 non-null   int64
# dtypes: bool(4), int64(6), object(5)
# memory usage: 408.4+ KB

# %%
notifications_df.sample(10)
# Out:
#            postTime     systemTime  isOngoing           when  isScreenOn  \
# 3994  1659732191487  1659732191727       True  1659732191481        True
# 524   1659671013249  1659671013520      False  1659635930000       False
# 3510  1659722677441  1659722677684       True  1659722677424        True
# 3804  1659729019618  1659729019942      False  1659706256000        True
# 1475  1659702415513  1659702415735      False  1659702415481       False
# 2621  1659714856972  1659714857203       True  1659714856963        True
# 2281  1659712548497  1659712548756       True  1659712548478       False
# 4321  1659738919114  1659738919481       True              0       False
# 1028  1659695608184  1659695608436       True              0        True
# 61    1659646963532  1659649736553      False  1659646963406        True
#
#       batteryLevel batteryStatus  isConnected connectionType  actionCount  \
# 3994            43   discharging         True           wifi            0
# 524             40   discharging         True           wifi            2
# 3510            52   discharging         True           wifi            0
# 3804            47   discharging         True           wifi            2
# 1475            29      charging         True           wifi            0
# 2621            55   discharging        False           none            0
# 2281            49   discharging         True           wifi            0
# 4321            32   discharging         True           wifi            0
# 1028             5      charging         True           wifi            0
# 61               9   discharging         True           wifi            1
#
#       isLocalOnly                                              title  \
# 3994        False                                        3,525 steps
# 524         False  ALUmni CLASS OF 2022 (10 messages): +250 789 6...
# 3510        False                                           WhatsApp
# 3804        False  Illustrators and creators (12 messages): +254 ...
# 1475        False                          Your data isn’t backed up
# 2621        False                                        1,090 steps
# 2281        False                                          506 steps
# 4321        False                         Today, used device 17m 55s
# 1028        False               Cable charging (6 h 48 m until full)
# 61          False         #05-career-support-data: Obinna Iheanachor
#
#                                                    text               appName  \
# 3994             You've achieved 58% of your step goal.        Samsung Health
# 524                                      Yea I know him              WhatsApp
# 3510                          Checking for new messages              WhatsApp
# 3804                             Ah yes, indeed. Thanks              WhatsApp
# 1475                           Add a backup account now  Google Play services
# 2621                        Your target is 6,000 steps.        Samsung Health
# 2281                        Your target is 6,000 steps.        Samsung Health
# 4321                             Checked device 1 times             App Usage
# 1028                           5% (6 h 48 m until full)             System UI
# 61    Hi @channel, we have come to the end of today'...                 Slack
#
#       priority
# 3994         2
# 524          0
# 3510        -1
# 3804         0
# 1475         1
# 2621         2
# 2281         2
# 4321        -2
# 1028        -2
# 61           0

# %%
# Checking for duplicate Notifications.
notifications_df.duplicated().sum()
# Out:
# 0

# %%
# Total Number of Applications that sent notifications to test phone.
len(notifications_df.appName.unique())
# Out:
# 43

# %%
# List of Apps that sent Notifications to the test phone
notifications_df.appName.unique()
# Out:
# array(['Chrome', 'Google', 'Google Play Store', 'Drive',
#        'Samsung capture', 'Google Play services', 'Analytics Vidhya',
#        'LinkedIn', 'Crowd Evolution!', 'A downloader for Instagram',
#        'Chelsea', 'Duo', 'Samsung account', 'Twitter', 'Pinterest',
#        'Instagram', 'YouTube', 'TikTok Lite', 'Facebook', 'System UI',
#        'Truecaller', 'Slack', 'Snapchat', 'WhatsApp', 'Gmail',
#        'Samsung Health', 'DataCamp', 'Weather', 'Samsung Cloud', 'Clock',
#        'Call', 'Messages', 'Package installer', 'App Usage', 'Asana',
#        'Edge panels', 'Shazam', 'Galaxy Themes', 'XRecorder',
#        'Android System', 'Samsung Music', 'Airbnb', 'DStv'], dtype=object)

# %%
notifications_df['priority'].unique()

# %%
# Checking for Null Values
notifications_df.isnull().sum()
# Out:
# postTime            0
# systemTime          0
# isOngoing           0
# when                0
# isScreenOn          0
# batteryLevel        0
# batteryStatus       0
# isConnected         0
# connectionType      0
# actionCount         0
# isLocalOnly         0
# title             129
# text              413
# appName             0
# priority            0
# dtype: int64

# %%
notifications_df[notifications_df['title'].isnull()]
# Out:
#            postTime     systemTime  isOngoing           when  isScreenOn  \
# 2     1659647949572  1659649734675      False  1659647949548        True
# 7     1659647111848  1659649734832      False  1659647111817        True
# 29    1659625814596  1659649735661      False  1659625814595        True
# 45    1659639869360  1659649736223      False  1659639869360        True
# 50    1659642612512  1659649736296      False  1659642612496        True
# ...             ...            ...        ...            ...         ...
# 4318  1659737866085  1659737866313      False  1659737866067        True
# 4319  1659737868230  1659737868463      False  1659737868162        True
# 4322  1659739325644  1659739344947       True  1659739325629        True
# 4330  1659739755012  1659739755290      False  1659739754993        True
# 4483  1659741917060  1659741917320      False  1659741916968        True
#
#       batteryLevel batteryStatus  isConnected connectionType  actionCount  \
# 2                9   discharging         True           wifi            0
# 7                9   discharging         True           wifi            0
# 29               9   discharging         True           wifi            0
# 45               9   discharging         True           wifi            0
# 50               9   discharging         True           wifi            0
# ...            ...           ...          ...            ...          ...
# 4318            35   discharging         True           wifi            0
# 4319            35   discharging         True           wifi            0
# 4322            31   discharging         True           wifi            0
# 4330            30   discharging         True           wifi            0
# 4483            25   discharging         True           wifi            0
#
#       isLocalOnly title       text      appName  priority
# 2           False   NaN        NaN       Google        -1
# 7           False   NaN        NaN        Drive         0
# 29           True   NaN        NaN      Chelsea         0
# 45           True   NaN        NaN  TikTok Lite         0
# 50           True   NaN        NaN     Facebook         0
# ...           ...   ...        ...          ...       ...
# 4318        False   NaN        NaN       Google        -1
# 4319        False   NaN        NaN       Google        -1
# 4322        False   NaN  Updating…      Weather         0
# 4330        False   NaN        NaN       Google        -2
# 4483        False   NaN        NaN       Google        -2
#
# [129 rows x 15 columns]

# %% [markdown]
# ### Correcting Incorrectly tagged data types.
#
# Convert __postTime__, __systemTime__ & __when__ columns to from integer type to datetime data type

# %%
import datetime

# Converting appropriate columsn to datetime
notifications_df['postTime'] = pd.to_datetime(notifications_df['postTime'], unit='ms')
notifications_df['systemTime'] = pd.to_datetime(notifications_df['systemTime'], unit='ms')
notifications_df['when'] = pd.to_datetime(notifications_df['when'], unit='ms')

# %%
notifications_df.sample(5)
# Out:
#                     postTime              systemTime  isOngoing  \
# 4279 2022-08-05 21:32:33.676 2022-08-05 21:32:44.013       True
# 4304 2022-08-05 21:42:40.618 2022-08-05 22:13:02.196       True
# 2942 2022-08-05 16:12:50.850 2022-08-05 16:12:51.126       True
# 4531 2022-08-05 23:46:36.836 2022-08-05 23:46:37.073       True
# 3160 2022-08-05 17:06:06.936 2022-08-05 17:06:07.708      False
#
#                         when  isScreenOn  batteryLevel batteryStatus  \
# 4279 2022-08-05 21:32:33.654       False            39   discharging
# 4304 2022-08-05 15:54:49.674       False            36   discharging
# 2942 2022-08-05 16:12:50.818        True            54   discharging
# 4531 1970-01-01 00:00:00.000        True            22   discharging
# 3160 2022-08-05 14:19:05.000        True            54   discharging
#
#       isConnected connectionType  actionCount  isLocalOnly  \
# 4279         True           wifi            0        False
# 4304         True           wifi            4        False
# 2942        False           none            0        False
# 4531         True           wifi            0        False
# 3160         True         mobile            2        False
#
#                                        title  \
# 4279                             5,068 steps
# 4304  SirensCeol - Coming Home [NCS Release]
# 2942                             1,440 steps
# 4531               Today, used device 1h 12m
# 3160                 M-PIRE: +254 716 883199
#
#                                                    text         appName  \
# 4279             You've achieved 84% of your step goal.  Samsung Health
# 4304                                            Unknown   Samsung Music
# 2942                        Your target is 6,000 steps.  Samsung Health
# 4531                             Checked device 4 times       App Usage
# 3160  Hi,\r\nI'm playing Fantasy Football Manager in...        WhatsApp
#
#       priority
# 4279         2
# 4304         0
# 2942         2
# 4531        -2
# 3160         0

# %%
notifications_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4544 entries, 0 to 4543
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   postTime        4544 non-null   datetime64[ns]
#  1   systemTime      4544 non-null   datetime64[ns]
#  2   isOngoing       4544 non-null   bool
#  3   when            4544 non-null   datetime64[ns]
#  4   isScreenOn      4544 non-null   bool
#  5   batteryLevel    4544 non-null   int64
#  6   batteryStatus   4544 non-null   object
#  7   isConnected     4544 non-null   bool
#  8   connectionType  4544 non-null   object
#  9   actionCount     4544 non-null   int64
#  10  isLocalOnly     4544 non-null   bool
#  11  title           4415 non-null   object
#  12  text            4131 non-null   object
#  13  appName         4544 non-null   object
#  14  priority        4544 non-null   int64
# dtypes: bool(4), datetime64[ns](3), int64(3), object(5)
# memory usage: 408.4+ KB

# %%
notifications_df.describe()
# Out:
#        batteryLevel  actionCount     priority
# count   4544.000000  4544.000000  4544.000000
# mean      39.175176     0.427817    -0.424076
# std       16.410354     0.906397     1.571385
# min        0.000000     0.000000    -2.000000
# 25%       27.000000     0.000000    -2.000000
# 50%       45.000000     0.000000    -1.000000
# 75%       54.000000     0.000000     1.000000
# max       56.000000     4.000000     2.000000

# %% [markdown]
# # Analysis
#
# Analysis Questions.
#
#         1. What are the top 10 Applications that triggered the highest amount of notifications in the 30+ hours of data collection?
#         2. Which applications triggered more user actions?
#         3. Within what timeframe did notifications peak over the 30+ hours of data collection?
#         4. Does a correlation exist between a notification's priority rating and its actionCount?

# %% [markdown]
# # 1. What are the top 10 Applications that triggered the highest amount of notifications in the 30+ hours of data collection?
#
# This question seeks to investigate the top 10 applications that sent the highest notification traffic to the mobile device. This will help us understand which applications are most active in sending notifications to my personal mobile device.

# %%
# Count Number of Notifications for each Application Logged
notifications_df.appName.value_counts()
# Out:
# Samsung Health                955
# App Usage                     948
# System UI                     850
# WhatsApp                      615
# Google Play Store             338
# Google                        197
# Android System                 82
# Call                           76
# Samsung Music                  70
# Google Play services           57
# Truecaller                     55
# Crowd Evolution!               52
# Gmail                          49
# YouTube                        36
# Chrome                         22
# Chelsea                        15
# Weather                        15
# Slack                          14
# Facebook                       10
# TikTok Lite                    10
# XRecorder                      10
# Twitter                         9
# LinkedIn                        8
# Instagram                       6
# Pinterest                       5
# Messages                        5
# Samsung capture                 4
# Package installer               4
# Samsung Cloud                   4
# Analytics Vidhya                3
# Clock                           3
# Asana                           2
# Drive                           2
# DStv                            2
# Snapchat                        2
# Edge panels                     2
# Airbnb                          1
# Samsung account                 1
# DataCamp                        1
# Duo                             1
# A downloader for Instagram      1
# Shazam                          1
# Galaxy Themes                   1
# Name: appName, dtype: int64

# %%
c.appName
# Out:
# <AxesSubplot:>

# %%
sns.set(font_scale=1.4)
notifications_df['appName'].value_counts().plot(kind='bar', figsize=(7, 6), rot=0)
plt.xlabel("Mobile Applications", labelpad=14)
plt.ylabel("Number of Notifications", labelpad=14)
plt.title("Top 10 Apps by Notification Frequency", y=1.02);
